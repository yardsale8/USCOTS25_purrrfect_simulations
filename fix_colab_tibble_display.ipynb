# %% [markdown]
# <a href="https://colab.research.google.com/github/yardsale8/USCOTS25_purrrfect_simulations/blob/main/fix_colab_tibble_display.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # First, fix a `Colab` display bug.
#
# #### Step 1 - Unload and reinstall the `repr` library.

# %%
library(devtools)
unload('repr')
install_github('IRkernel/repr', force = TRUE)
library(repr)

# Output may show an error because we unloaded repr.
# Out:
# Loading required package: usethis
#
# ...
# ── R CMD build ─────────────────────────────────────────────────────────────────
# * checking for file ‘/tmp/RtmpWXylAZ/remotesa6736b156e/IRkernel-repr-8809fc9/DESCRIPTION’ ... OK
# * preparing ‘repr’:
# * checking DESCRIPTION meta-information ... OK
# * checking for LF line-endings in source and make files and shell scripts
# * checking for empty or unneeded directories
# * building ‘repr_1.1.7.tar.gz’
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Warning message in get(Info[i, 1], envir = env):
# “internal error 1 in R_decompress1 with libdeflate”
# Error: package or namespace load failed for ‘repr’ in get(Info[i, 1], envir = env):
#  lazy-load database '/usr/local/lib/R/site-library/repr/R/repr.rdb' is corrupt
# Traceback:
#
# 1. tryCatch({
#  .     attr(package, "LibPath") <- which.lib.loc
#  .     ns <- loadNamespace(package, lib.loc)
# ...

# %% [markdown]
# #### Step 2 - Restart the session as needed
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### Step 3 - Load the needed libraries (START HERE after restarting session).

# %%
library(tidyverse)
library(devtools)
install_github('yardsale8/purrrfect', force = TRUE)
library(purrrfect)

statistic <- map_vec
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.2     ✔ tibble    3.3.0
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.0.4
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Loading required package: usethis
#
# ...
# ── R CMD build ─────────────────────────────────────────────────────────────────
# * checking for file ‘/tmp/RtmpSieDC5/remotes1a855934aa8/yardsale8-purrrfect-09dd705/DESCRIPTION’ ... OK
# * preparing ‘purrrfect’:
# * checking DESCRIPTION meta-information ... OK
# Warning in person1(given = given[[i]], family = family[[i]], middle = middle[[i]],  :
#   Invalid ORCID iD: ‘YOUR-ORCID-ID’.
# ...

# %% [markdown]
# #### Step 4 - Verify the following code runs without an error

# %%
replicate(4, sample(1:4, 2, replace = TRUE))
# Out:
#   .trial .outcome
# 1 1      2, 3
# 2 2      1, 3
# 3 3      4, 3
# 4 4      1, 2

# %% [markdown]
# ## Proceed with rest of notebook
#
# ...
